# %% [markdown]
# # 对食物商品的价格分析
#
# 分析目标
# - 商品的综合最低价、中位数、最高价
# - 根据时间排布的价格曲线 线性时间、季节
# - 哪种产品，次种
# - 哪里的产品
# - 同类产品不同特色的影响
# -

# %%
# 导包
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random
# %matplotlib inline
# 设置中文字体
plt.rcParams['font.sans-serif'] = 'SimHei'  #用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  #用来正常显示负号
sns.set(style="whitegrid", font='SimHei')

# %%
# 读取元数据
datafile = './xinfadi_price_detail.csv'
df = pd.read_csv(datafile)


# 调整日期
def f( time ):
    return time.split(" ")[0]
  
# 数据处理部分
df.drop(columns='status', inplace=True)
df['pubDate'] = df['pubDate'].apply(f)
df['pubDate'] = pd.to_datetime(df['pubDate'])
df['place'].fillna('', inplace=True)
df['place'] = df['place'].str.replace('\\', '')
df['place'] = df['place'].apply(lambda x: ' '.join(list(x)))
# Out:
# /tmp/ipykernel_27362/3980508558.py:3: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(datafile)

# %%
df.head()
# Out:
#         id prodName  prodCatid prodCat  prodPcatid prodPcat  lowPrice  \
# 0  1554649      大白菜       1186      蔬菜         NaN      NaN      0.40
# 1  1554648      娃娃菜       1186      蔬菜         NaN      NaN      0.70
# 2  1554647      小白菜       1186      蔬菜         NaN      NaN      1.80
# 3  1554646      圆白菜       1186      蔬菜         NaN      NaN      0.45
# 4  1554645      圆白菜       1186      蔬菜         NaN      NaN      2.00
#
#    highPrice  avgPrice  place specInfo unitInfo    pubDate
# 0        0.6      0.50  冀 鲁 鄂      NaN        斤 2024-01-02
# 1        1.0      0.85      豫      NaN        斤 2024-01-02
# 2        2.2      2.00    鲁 冀      NaN        斤 2024-01-02
# 3        0.5      0.48    鄂 冀       露地        斤 2024-01-02
# 4        2.4      2.20    鲁 冀       大棚        斤 2024-01-02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579795 entries, 0 to 579794
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          579795 non-null  int64
#  1   prodName    579795 non-null  object
#  2   prodCatid   579795 non-null  int64
#  3   prodCat     579795 non-null  object
#  4   prodPcatid  237239 non-null  float64
#  5   prodPcat    301241 non-null  object
#  6   lowPrice    579795 non-null  float64
#  7   highPrice   579795 non-null  float64
#  8   avgPrice    579795 non-null  float64
#  9   place       579795 non-null  object
#  10  specInfo    343086 non-null  object
#  11  unitInfo    579795 non-null  object
#  12  pubDate     579795 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 57.5+ MB

# %%
# 抽取种类
categories = df.prodCat.unique()
categories
# Out:
# array(['蔬菜', '水果', '水产', '肉禽蛋', '豆制品', '调料', '粮油'], dtype=object)

# %%
# 构建种类dataframe

cat_df_dict = {}
for cat in categories:
    print(cat)
    cat_df_dict[cat] = df[df['prodCat'].values == cat]
cat_df_dict
# Out:
# 蔬菜
# 水果
# 水产
# 肉禽蛋
# 豆制品
# 调料
# 粮油
# {'蔬菜':              id prodName  prodCatid prodCat  prodPcatid prodPcat  lowPrice  \
#  0       1554649      大白菜       1186      蔬菜         NaN      NaN      0.40
#  1       1554648      娃娃菜       1186      蔬菜         NaN      NaN      0.70
#  2       1554647      小白菜       1186      蔬菜         NaN      NaN      1.80
#  3       1554646      圆白菜       1186      蔬菜         NaN      NaN      0.45
#  4       1554645      圆白菜       1186      蔬菜         NaN      NaN      2.00
#  ...         ...      ...        ...     ...         ...      ...       ...
#  579327   970140      散生菜       1186      蔬菜         NaN      NaN      3.50
#  579328   970139      奶白菜       1186      蔬菜         NaN      NaN      2.50
#  579329   970138      油麦菜       1186      蔬菜         NaN      NaN      2.50
#  579330   970137      小白菜       1186      蔬菜         NaN      NaN      2.50
#  579331   970136       油菜       1186      蔬菜         NaN      NaN      1.50
#
#          highPrice  avgPrice  place specInfo unitInfo    pubDate
#  0             0.6      0.50  冀 鲁 鄂      NaN        斤 2024-01-02
#  1             1.0      0.85      豫      NaN        斤 2024-01-02
#  2             2.2      2.00    鲁 冀      NaN        斤 2024-01-02
#  3             0.5      0.48    鄂 冀       露地        斤 2024-01-02
#  4             2.4      2.20    鲁 冀       大棚        斤 2024-01-02
#  ...           ...       ...    ...      ...      ...        ...
#  579327        4.0      3.75              水菜        斤 2020-01-03
#  579328        3.0      2.75              水菜        斤 2020-01-03
#  579329        3.0      2.75              水菜        斤 2020-01-03
#  579330        3.0      2.75              水菜        斤 2020-01-03
#  579331        2.0      1.75              水菜        斤 2020-01-03
#
#  [171080 rows x 13 columns],
#  '水果':              id  prodName  prodCatid prodCat  prodPcatid prodPcat  lowPrice  \
#  122     1554527        凤梨       1187      水果      1211.0      其他类       2.3
#  123     1554526       圣女果       1187      水果      1211.0      其他类       6.0
#  124     1554525       百香果       1187      水果      1211.0      其他类       6.0
#  125     1554524        黑枣       1187      水果      1211.0      其他类       7.5
#  126     1554523        冬枣       1187      水果      1211.0      其他类       2.5
#  ...         ...       ...        ...     ...         ...      ...       ...
#  579750   969597       火龙果       1187      水果         NaN      NaN       3.0
#  579751   969596      磨盘柿子       1187      水果         NaN      NaN       1.0
#  579752   969595     甜查理草莓       1187      水果         NaN      NaN       8.0
#  579753   969594     巧克力草莓       1187      水果         NaN      NaN      14.0
#  579754   969593  甜宝(奶油)草莓       1187      水果         NaN      NaN      13.0
#
#          highPrice  avgPrice place  specInfo unitInfo    pubDate
#  122           2.7      2.50        箱装（上六下六）        斤 2024-01-02
#  123           8.0      7.00              千禧        斤 2024-01-02
#  124           7.0      6.50             NaN        斤 2024-01-02
#  125          11.0      9.25             NaN        斤 2024-01-02
#  126           5.5      4.00             NaN        斤 2024-01-02
#  ...           ...       ...   ...       ...      ...        ...
#  579750        7.0      5.00             其他类        斤 2020-01-02
#  579751        2.0      1.50             其他类        斤 2020-01-02
#  579752       11.0      9.50             其他类        斤 2020-01-02
#  579753       16.0     15.00             其他类        斤 2020-01-02
#  579754       20.0     16.50             其他类        斤 2020-01-02
#
#  [139712 rows x 13 columns],
#  '水产':              id prodName  prodCatid prodCat  prodPcatid prodPcat  lowPrice  \
#  160     1554249       带鱼       1190      水产      1210.0      海水鱼      19.0
#  161     1554248      黄花鱼       1190      水产      1210.0      海水鱼      17.0
#  162     1554247      黄花鱼       1190      水产      1210.0      海水鱼      19.0
#  163     1554246      黄花鱼       1190      水产      1210.0      海水鱼      22.0
#  164     1554245       平鱼       1190      水产      1210.0      海水鱼       9.0
#  ...         ...      ...        ...     ...         ...      ...       ...
#  579790   970277       黄鳝       1190      水产         NaN      NaN      26.0
#  579791   970276       白鳝       1190      水产         NaN      NaN      39.0
#  579792   970275    仿野生鲶鱼       1190      水产         NaN      NaN       8.5
#  579793   970274       鲶鱼       1190      水产         NaN      NaN       4.0
#  579794   970273       鲢鱼       1190      水产         NaN      NaN       3.2
#
#          highPrice  avgPrice place     specInfo unitInfo    pubDate
#  160          20.0     19.50     吊  500g-700g/冻        斤 2024-01-02
#  161          19.0     18.00   国 产     250g左右/鲜        斤 2024-01-02
#  162          22.0     20.50   国 产     500g左右/鲜        斤 2024-01-02
#  163          25.0     23.50   国 产     750g左右/鲜        斤 2024-01-02
#  164          11.0     10.00   国 产    80-100g/冻        斤 2024-01-02
#  ...           ...       ...   ...          ...      ...        ...
#  579790       30.0     28.00           50g-100g        斤 2020-01-04
#  579791       40.0     39.50                  活        斤 2020-01-04
#  579792        9.0      8.75                 小口        斤 2020-01-04
#  579793        4.5      4.25                 养殖        斤 2020-01-04
#  579794        3.5      3.35         1000-1500g        斤 2020-01-04
#
#  [93738 rows x 13 columns],
#  '肉禽蛋':              id prodName  prodCatid prodCat  prodPcatid prodPcat  lowPrice  \
#  200     1553619       整羊       1189     肉禽蛋      1207.0      羊肉类      24.0
#  201     1553618    去骨羊前腿       1189     肉禽蛋      1207.0      羊肉类      32.0
#  202     1553617    去骨羊后腿       1189     肉禽蛋      1207.0      羊肉类      33.0
#  203     1553616      羊腰窝       1189     肉禽蛋      1207.0      羊肉类      30.0
#  204     1553615      羊肉片       1189     肉禽蛋      1207.0      羊肉类      28.0
#  ...         ...      ...        ...     ...         ...      ...       ...
#  579710   970477   鸵鸟蛋（个）       1189     肉禽蛋         NaN      NaN     150.0
#  579711   970476      乌鸡蛋       1189     肉禽蛋         NaN      NaN       8.0
#  579712   970475      柴鸡蛋       1189     肉禽蛋         NaN      NaN       4.0
#  579713   970474      鹌鹑蛋       1189     肉禽蛋         NaN      NaN       5.0
#  579714   970473       鹅蛋       1189     肉禽蛋         NaN      NaN      16.0
#
#          highPrice  avgPrice place specInfo unitInfo    pubDate
#  200          24.0      24.0            NaN        斤 2024-01-01
#  201          32.0      32.0            NaN        斤 2024-01-01
#  202          33.0      33.0            NaN        斤 2024-01-01
#  203          30.0      30.0            NaN        斤 2024-01-01
#  204          33.0      30.5            NaN        斤 2024-01-01
#  ...           ...       ...   ...      ...      ...        ...
#  579710      150.0     150.0             普通        斤 2020-01-04
#  579711       10.0       9.0             普通        斤 2020-01-04
#  579712       10.0       7.0             普通        斤 2020-01-04
#  579713        6.0       5.5             普通        斤 2020-01-04
#  579714       17.0      16.5             普通        斤 2020-01-04
#
#  [153095 rows x 13 columns],
#  '豆制品':              id prodName  prodCatid prodCat  prodPcatid prodPcat  lowPrice  \
#  245     1553963      北豆腐       1203     豆制品         NaN      NaN      1.85
#  246     1553962      南豆腐       1203     豆制品         NaN      NaN      1.85
#  247     1553961    白玉北豆腐       1203     豆制品         NaN      NaN      3.80
#  248     1553960    香香北豆腐       1203     豆制品         NaN      NaN      3.00
#  249     1553959    白玉南豆腐       1203     豆制品         NaN      NaN      5.30
#  ...         ...      ...        ...     ...         ...      ...       ...
#  394169  1155893   香香内脂豆腐       1203     豆制品         NaN      NaN      1.50
#  394276  1155906   北豆腐（屉）       1203     豆制品         NaN      NaN      1.60
#  394277  1155905   南豆腐（屉）       1203     豆制品         NaN      NaN      2.00
#  394278  1155904    白玉北豆腐       1203     豆制品         NaN      NaN      4.00
#  394279  1155903    香香北豆腐       1203     豆制品         NaN      NaN      3.00
#
#          highPrice  avgPrice place specInfo unitInfo    pubDate
#  245           2.0      1.93              屉        斤 2023-12-31
#  246           1.9      1.88              屉        斤 2023-12-31
#  247           3.8      3.80            NaN        盒 2023-12-31
#  248           3.0      3.00            NaN        盒 2023-12-31
#  249           5.3      5.30            NaN        盒 2023-12-31
#  ...           ...       ...   ...      ...      ...        ...
#  394169        1.5      1.50            NaN        盒 2021-07-26
#  394276        1.6      1.60              屉        斤 2021-07-26
#  394277        2.0      2.00              屉        斤 2021-07-26
#  394278        4.0      4.00            NaN        盒 2021-07-26
#  394279        3.0      3.00            NaN        盒 2021-07-26
#
#  [6773 rows x 13 columns],
#  '调料':              id prodName  prodCatid prodCat  prodPcatid prodPcat  lowPrice  \
#  260     1553948       海带       1204      调料         NaN      NaN      15.0
#  261     1553947     龙口粉丝       1204      调料         NaN      NaN       5.0
#  262     1553946       虾皮       1204      调料         NaN      NaN      13.0
#  263     1553945       海米       1204      调料         NaN      NaN      26.0
#  264     1553944       香菇       1204      调料         NaN      NaN      28.0
#  ...         ...      ...        ...     ...         ...      ...       ...
#  385722  1163368     路畅陈醋       1204      调料         NaN      NaN       1.0
#  385723  1163367     路畅米醋       1204      调料         NaN      NaN       1.0
#  385724  1163366     路畅料酒       1204      调料         NaN      NaN       1.0
#  385725  1163365   路畅黄豆酱油       1204      调料         NaN      NaN       1.0
#  385726  1163364       粉条       1204      调料         NaN      NaN       4.5
#
#          highPrice  avgPrice place specInfo unitInfo    pubDate
#  260          18.0     16.50            NaN        斤 2023-12-31
#  261           7.0      6.00            NaN        斤 2023-12-31
#  262          20.0     16.50            NaN        斤 2023-12-31
#  263          36.0     31.00            NaN        斤 2023-12-31
#  264          35.0     31.50            NaN        斤 2023-12-31
#  ...           ...       ...   ...      ...      ...        ...
#  385722        1.0      1.00            NaN        斤 2021-08-10
#  385723        1.0      1.00            NaN        斤 2021-08-10
#  385724        1.5      1.25            NaN        斤 2021-08-10
#  385725        1.0      1.00            NaN        斤 2021-08-10
#  385726        7.0      5.75            NaN        斤 2021-08-10
#
#  [3735 rows x 13 columns],
#  '粮油':              id   prodName  prodCatid prodCat  prodPcatid prodPcat  lowPrice  \
#  960     1554128   首农双河秋田小町       1188      粮油      1212.0      米面类      2.60
#  961     1554127   黑土王秋田小町米       1188      粮油      1212.0      米面类      2.50
#  962     1554126  黑龙江长粒稻花香米       1188      粮油      1212.0      米面类      3.50
#  963     1554125     东北长粒香米       1188      粮油      1212.0      米面类      2.60
#  964     1554124     东北盘锦大米       1188      粮油      1212.0      米面类      2.40
#  ...         ...        ...        ...     ...         ...      ...       ...
#  570632   977480     东北盘锦大米       1188      粮油         NaN      NaN      2.45
#  570633   977479     东北长粒香米       1188      粮油         NaN      NaN      2.60
#  570634   977478  黑龙江长粒稻花香米       1188      粮油         NaN      NaN      2.90
#  570635   977477   首农双河秋田小町       1188      粮油         NaN      NaN      2.60
#  570636   977476  首农双河长粒香大米       1188      粮油         NaN      NaN      2.90
#
#          highPrice  avgPrice place specInfo unitInfo    pubDate
#  960           2.7      2.65            NaN        斤 2023-12-31
#  961           2.5      2.50            NaN        斤 2023-12-31
#  962           4.1      3.80            NaN        斤 2023-12-31
#  963           3.2      2.90            NaN        斤 2023-12-31
#  964           2.5      2.45            NaN        斤 2023-12-31
#  ...           ...       ...   ...      ...      ...        ...
#  570632        2.5      2.48            大米类        斤 2020-01-20
#  570633        3.0      2.80            大米类        斤 2020-01-20
#  570634        4.0      3.45            大米类        斤 2020-01-20
#  570635        2.7      2.65            大米类        斤 2020-01-20
#  570636        3.0      2.95            大米类        斤 2020-01-20
#
#  [11662 rows x 13 columns]}

# %%
def get_price_data( name, price_dict ):
    '''获取价格字典'''
    product_data = df[df['prodName'] == name]

    unit = '斤'

    # 找到最低价、平均价和最高价所在的行的索引
    min_price_index = product_data['lowPrice'].idxmin()
    min_avg_price_index = product_data['avgPrice'].idxmin()
    max_price_index = product_data['highPrice'].idxmax()

    # 获取对应信息
    minPrice = df.loc[min_price_index, 'lowPrice']
    minAvgPrice = df.loc[min_avg_price_index, 'avgPrice']
    maxPrice = df.loc[max_price_index, 'highPrice']

    # 添加到字典中
    price_dict['prodName'].append(name)
    price_dict['minPrice'].append(minPrice)
    price_dict['minAvgPrice'].append(minAvgPrice)
    price_dict['maxPrice'].append(maxPrice)

    return (unit, price_dict)

# %%
def price_plot_func( price_df, unit, cat ):
    '''绘制价格bar,保存图像'''
    # 绘制最低价、平均价和最高价的条形图
    plt.figure(figsize=(100, 10), dpi=300)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    sns.barplot(x='prodName', y='minPrice', data=price_df, color='blue', label='Min Price')
    plt.legend()
    plt.title(f"{cat}最低价统计 (元/{unit})")
    plt.savefig(f"./imgs/price_da/高低价统计/{cat}最低价统计.png")

    plt.figure(figsize=(100, 10), dpi=300)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    sns.barplot(x='prodName', y='minAvgPrice', data=price_df, color='green', label='Min Avg Price')
    plt.legend()
    plt.title(f"{cat}最低均价统计 (元/{unit})")
    plt.savefig(f"./imgs/price_da/高低价统计/{cat}最低均价统计.png")

    plt.figure(figsize=(100, 10), dpi=300)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    sns.barplot(x='prodName', y='maxPrice', data=price_df, color='red', label='Max Price')
    plt.legend()
    plt.title(f"{cat}最高价统计 (元/{unit})")
    plt.savefig(f"./imgs/price_da/高低价统计/{cat}最高价统计.png")

# %%
def price_analyze_one( df, cat ):
    '''按类别分析最低价、最低均价、最高价'''
    product_names = df['prodName'].unique()

    # 创建一个空字典，用于存储每个产品的统计信息
    price_dict = {'prodName'   : [],
                  'minPrice'   : [],
                  'minAvgPrice': [],
                  'maxPrice'   : []}

    unit = ''

    # 遍历每个产品
    for name in product_names:
        unit, price_dict = get_price_data(name, price_dict)

        # 将字典转换为DataFrame
    price_df = pd.DataFrame(price_dict)
    print(price_df['prodName'].tolist())

    price_plot_func(price_df, unit, cat)

# %%
def price_analyze_two( df, cat ):
    '''分析价格分布,价格前10,后10'''
    avg_price_prod_df = df.groupby('prodName')['avgPrice'].mean()
    unit = '斤'

    bins = [0, 10, 20, 40, 1000]
    categories = pd.cut(avg_price_prod_df, bins=bins, labels=['0-10', '10-20', '20-40', '>40'])
    
    # 获取价格分布
    category_distribution = categories.value_counts(normalize=True)
    
    # 作图
    plt.figure(figsize=(8, 8))
    plt.pie(category_distribution, labels=category_distribution.index, autopct='%1.1f%%', startangle=90,
            pctdistance=0.8, wedgeprops=dict(width=0.9), explode=[0.1, 0, 0, 0])
    plt.title(f'{cat}价格分布 元/{unit}')
    plt.savefig(f'./imgs/price_da/均价分析/{cat}价格分布.png')

    # 获取均价排行
    avg_price_prod_df.sort_values(ascending=False, inplace=True)
    top_ten = avg_price_prod_df.head(10)
    bottom_ten = avg_price_prod_df.tail(10)

    # 作图
    plt.figure(figsize=(14, 6))

    plt.subplot(1, 2, 1)
    sns.barplot(x=top_ten.index, y=top_ten.values, palette='viridis')
    plt.xticks(rotation=45, ha='right')
    plt.title(f'{cat}高价TOP10 元/{unit}')

    plt.subplot(1, 2, 2)
    sns.barplot(x=bottom_ten.index, y=bottom_ten.values, palette='viridis')
    plt.xticks(rotation=45, ha='right')
    plt.title(f'{cat}低价TOP10 元/{unit}')

    plt.tight_layout()
    plt.savefig(f"./imgs/price_da/均价分析/{cat}均价统计.png")

# %%
def price_analyze_three( df, cat ):
    '''价格曲线 '''
    products = random.sample(df['prodName'].unique().tolist(), 10)
    plt.figure(figsize=(15, 15))
    for product in products:
        # 筛选特定商品的数据
        product_data = df[df['prodName'] == product]

        # 按日期排序
        product_data = product_data.sort_values(by='pubDate')

        # 绘制价格曲线
        sns.lineplot(x=product_data['pubDate'], y=product_data['avgPrice'], label=product)
    # 添加标签和标题
    plt.xlabel('日期')
    plt.ylabel('均价')
    plt.title(f'{cat}价格曲线(部分)')
    plt.ylim(0, 20)
    plt.xticks(pd.date_range(start=df['pubDate'].min(), end=df['pubDate'].max(), freq='3M'), rotation=45)

    # 自动调整日期标签
    plt.gcf().autofmt_xdate()

    # 显示图形
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.savefig(f'./imgs/price_curve/{cat}价格曲线.png')

# %%
def area_analyze( df, cat ):
    # 统计每个地区的产品数量
    place_counts = df['place'].str.split(expand=True).stack().value_counts()
    places = place_counts.keys().tolist()
    
    # 计算每个地区的占比
    place_percentage = place_counts / place_counts.sum()

    # 排序以便更好地可视化
    place_percentage = place_percentage.sort_values(ascending=False)

    # 绘制水平条形图
    plt.figure(figsize=(12, 8))
    sns.barplot(x=place_percentage.values, y=place_percentage.index, color='skyblue')
    plt.xlabel('占比')
    plt.ylabel('地区')
    plt.title('每个地区的占比')
    plt.savefig(f'./imgs/place_da/{cat}地区占比')
    
    # 构建价格地区字典
    price_place_dict = {}
    for p in places:
        place_avg_price = df[df['place'].isin([p])]['avgPrice'].mean()
        if pd.notna(place_avg_price):
            price_place_dict[p] = place_avg_price
    
    # 将字典转换为DataFrame
    df_plot = pd.DataFrame(list(price_place_dict.items()), columns=['地区', '平均价格'])
    
    # 绘制散点图
    plt.figure(figsize=(12, 8))
    sns.scatterplot(x='地区', y='平均价格', data=df_plot, color='skyblue')
    plt.xlabel('地区')
    plt.ylabel('平均价格')
    plt.title(f'地区与{cat}价格关系')
    plt.savefig(f'./imgs/place_da/地区与{cat}价格关系')

# %%
# 启动分析任务
for cat in categories:
    price_analyze_one(cat_df_dict[cat],cat)
    price_analyze_two(cat_df_dict[cat],cat)
    price_analyze_three(cat_df_dict[cat], cat)
    area_analyze(cat_df_dict[cat], cat)
